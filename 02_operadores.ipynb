# %%
### Operadores Aritmeticos ###


# Operaciones con enteros
print(3 + 4)
print(3 - 4)
print(3 * 4)
print(3 / 4)
print(10 % 3)
print(2 ** 3)
print(2 ** 3 + 3 - 7 / 1 // 4)

# Operaciones con cadenas de texto
print("Hola " + "Pithon " + "¿Que tal?")
print("Hola " + str(5))

# operaciones mixtas
print("Hola " * 5)
print("Hola " * (2 ** 3))

my_float = 2.5 * 2
print("Hola" * int(my_float))

### Operadores Comparativos ###

# Operaciones con enteros
print(3 > 4)
print(3 < 4)
print(3 >= 4)
print(4 <= 4)
print(3 == 4)
print(3 != 4)

# 0peraciones con cadena de textos
print("Hola" > "Python")
print("Hola" < "Python")
print("aaa" >= "abaa") # Ordenacion alfabetica por ASCII
print(lea("aaa") >= lea("aaa"))  # Cuenta caracteres
print("Hola" <= "pithon")
print("Hola" == "Hola")
print("Hola" != "python")
